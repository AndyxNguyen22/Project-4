# %% [markdown]
# ## INST326 Object Oriented Programming, Project 04

# %% [markdown]
# #### Andy Nguyen

# %% [markdown]
# In the cell below, state whether you completed this work in your group or individually. If you completed this in a group, provide the group number and names of other group members.

# %% [markdown]
# Individually

# %% [markdown]
# Include a link to your github repository. Place your final code and any additional files (note files, etc) in that repository.

# %% [markdown]
# https://github.com/AndyxNguyen22/Project-4

# %% [markdown]
# #### Project 04 Instructions

# %% [markdown]
# With project 04 you will take the basic note app that we have developed so far in projects 02 and 03, and really make it your own. Some of the improvements you might consider (these are ideas, not requirements):
#
#
# 1. Improving / simplifying / combining the note and snippet formats
# 2. Improving / simplifying the structure of the note program to make it cleaner and more object oriented
# 3. Create your own modules (remember that the modules will need to be turned in too)
# 4. Improve the overall visual display of the main window and notes:
#
#     1. Make the window larger
#     2. Add scroll bars and other widgets to the notes display
#     3. Load a default notebook when you start the program
#     4. Improve the way the notes are displayed in the main window
#     5. Improve the visual aesthetics of the display
#
# 5. Improve the pop up display of notes
# 6. Add snippet copy functionality so that snippets may be copied and pasted into programs
# 7. Add search functionality for your notes
# 8. Create a note share repository on github to share notes with other groups
# 9. Improve the save and read notebooks functionality to accomodate notebooks in different formats (txt, json, csv, xml)
# 10. create a utility program to convert notes from one format to another
# 11. Create a notes database in sqlite and add functionality to your program to read, write, and search notes in the database.
#
# For project 04 you are encouraged to continue working and collaborating in your groups. However, if your group dynamics are not good you may complete project 04 individually without penalty.
#
# Whether you continue working as a group or as an individual, each student must submit (upload) their final project on ELMS.
#
# For this project, each student must make or contribute to at least three improvements to the final note program as described above. Each student will also be responsible for at least ten (10) real notes and/or snippets, including those submitted under projects 02, 03, and an the discussions.
#
# For the base note app code you may start with either your group's code from project 03, or the project 03 solution provided on ELMS.

# %% [markdown]
# #### Instructions for this notebook

# %% [markdown]
# As the examples above suggest, each improvement should be non-trivial, and should make the program better in some way. At the same time, rewriting a section of code in a way that makes it more object oriented, or more resilient, is an acceptable improvement if you explain it well. I am looking for improvements that demonstrate your understanding of object oriented programming. Coding wizardry is not necessary. Choose improvements that are interesting and useful to you. If you do that, you are more likely to spend quality time on the project. That will be apparent in your work.
#
# In the cells below, identify and discuss the three improvements you made to the notes program. You should state:
# 1. what the improvement is in one sentence
# 2. describe the improvement in three sentences or less (if needed)
# 3. how it makes the program better
# 4. how it uses or relates to the principles of object oriented programming

# %% [markdown]
# #### Improvement # 1

# %% [markdown]
# I discovered that the "Created At" and "Last Edited" text was not visible on Mac if the user had dark mode on. I want to improve user appearance here. This is due to the both the background and text being white. I want the user to be able to see the text regardless of dark mode or light mode is on so I am changing the background color to display the text better. With his improvement, I had to make changes to the NoteForm class. Along with that my previous code had an issue where the "Last Edited" date would disaapear after the note was closed. I want the date to remain there. This improvement made it so the date would remain there and when the user opens up the notebook again, the "Last Edited" date is still displayed. This will allow the user always known when the last edited date is unlike before. To fix this I had to modify the Note and NoteForm Class.

# %% [markdown]
# #### Improvement # 2

# %% [markdown]
# My previouse code had the note text field shorter than the code text field. Also, the code text field was only one line. I felt like this wasn't enough space for the user. So I wanted the note text field to longer and wanted the code text to be multiple lines. I ultimately decided to make them both the same size. This change should allow the text fields to appear better to the user and allow more room to write. I had to make changes to the NoteFrom class

# %% [markdown]
# #### Improvement # 3

# %% [markdown]
# With the enlargement of the text fields, I felt like the addition of a scroll wheel could be nice for user experience. The user may not want a fully large window but then they can't see whats below. This is where a scroll wheel come in handy. So, I decided to add a scroll wheel both the MainWindow and the Note window. This required changes to the MainWindow and Note Form class. With this improvement, this ensures the user can see all parts of the window if the window is not fully enlarged. To do the scroll wheel, it required me to use tkinter, adding a frame, canvas, and the scrollbar function from tkinter.

# %% [markdown]
# #### Print your notes

# %% [markdown]
# In the cell below, print or copy your ten notes.

# %% [markdown]
# NOTE 1:
#     Title: Date and Time
#
#     now = datetime.datetime.now() # gets the current date and time
#     local_now = now.astimezone() # shows the local time and the GMT offset
#     local_tz = local_now.tzinfo
#
#     print(now)
#     print(local_now)
#     print(local_tz)
#
#     This code could be useful tracking the date and time with each note creation and note edits.
#
#
# NOTE 2:
#     Title: Fields for notes and code snippets.
#
#     # create our note title entry field
#     note_title = tk.Entry(root, width=80)
#     note_title.grid(padx=10, pady=10, row=1, column=1, sticky='w')
#     note_title.insert(0, 'New note title') # adds default text (useful during development)
#
#     # create our note text field
#     note_text = tk.Text(root, height=10, width=60)
#     note_text.grid(padx=10, pady=10, row=2, column=1)
#     note_text.insert('1.0', lorem) # adds default text (useful during development)
#
#     # create our note link entry field
#     note_link = tk.Entry(root, width=80)
#     note_link.grid(padx=10, pady=10, row=3, column=1, sticky='w')
#     note_link.insert(0, 'If there is a link with this note enter it here. Else, enter "None"') # adds default text (useful during development)
#
#     # create our note link entry field
#     note_tags = tk.Entry(root, width=80)
#     note_tags.grid(padx=10, pady=10, row=4, column=1, sticky='w')
#     note_tags.insert(0, 'Enter #tags, separated by commas')
#
#     This code can be used for or in aid of creation our note text fields along with a code snippet text field.
#
#     Tags: #Notes #Time #Date #Edit #Text #Fields #Entry
#
# NOTE 3:
#     Potential code that could be used to display code snippets. The code to display the code snippets won't look exactly alike but could be quite similar.
#
#     def display_note_window(self, note_text):
#         note_window = tk.Toplevel(self)
#         note_window.title("Note")
#         note_label = tk.Label(note_window, text=note_text, wraplength=500)
#         note_label.pack(padx=10, pady=10)
#
#
# NOTE 4:
#     The snippet class will need to be able to save and read the snippets. We could probably use something similar to that of Lab 03 in the snippet class.
#
#
#     # save as a text file here
#
#     with open ("notes1.txt", "w") as f:
#         for note in notes:
#             f.write(f"{note['title']}\n[notes['text'\n{note['meta']}\n")
#
#     # read in your text file here
#     new_notes = []
#     with open("notes1.txt","r") as f:
#         lines = f.readlines()
#         for i in range(0, len(lines), 3):
#             title = lines[i].strip()
#             text = lines[i+1].strip()
#             meta = lines[i+2].strip()
#             new_notes.append({'title':title, 'text':text, 'meta':meta})
#
#     # save as a csv file here
#     with open("notes1.csv", "w", newline = '') as csvfile:
#         fieldnames = ['titles', 'text', 'meta']
#         writer = csv.DictWriter(csvfile, fieldnames = fieldnames)
#         writer.writeheader()
#         for note in notes:
#             writer.writerow(note)
#
#
#     # read in your csv file here
#     new_notes_csv = []
#     with open("notes1.csv", "r", newline = '') as csvfile:
#         reader = csv.DictReader(csvfile)
#         for row in reader:
#             print(row)
#             new_notes_csv.append(row)
#         print(new_notes_csv)
#
#
#     # save your json file here
#     with open("notes1.json","w") as jsonfile:
#         json.dump(notes, jsonfile)
#
#     # read your json file here
#     with open("notes1.json", "r") as jsonfile:
#         new_notes_json = json.load(jsonfile)
#
#
#
# NOTE 5:
#      Scroll Notes:
#     Need to use tkinter, add a frame, canvas, the scrollbar function from tkinter,
#     configure the canvas, and create a frame inside the canvas.
#     EXAMPLE:
#     # create a frame for the scroll wheel
#         main_frame = tk.Frame(self)
#         main_frame.pack(fill=tk.BOTH, expand=True)
#
#         # add a canvas
#         canvas = tk.Canvas(main_frame)
#         canvas.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
#
#         # add the scrollbar
#         scrollbar = tk.Scrollbar(main_frame, orient=tk.VERTICAL, command=canvas.yview)
#         scrollbar.pack(side=tk.RIGHT, fill=tk.Y)
#
#         # configures the Canvas
#         canvas.configure(yscrollcommand=scrollbar.set)
#         canvas.bind('<Configure>', lambda e: canvas.configure(scrollregion=canvas.bbox("all")))
#
#         # create a frame inside the Canvas
#         self.notebook_frame = tk.Frame(canvas)
#         canvas.create_window((0, 0), window=self.notebook_frame, anchor=tk.NW)
#
#
# NOTE 6:
#     Button Notes:
#     Need to use Tkinter to create the button. Title goes in the same line as the tk code
#     Need to place the button somewhere using the .grid. Is done so by using rows and columns.
#     For Example:
#     create_button = tk.Button(self.notebook_frame, text='Create New Note', command=self.new_note)
#     create_button.grid(row=0, column=0, padx=10, pady=10)
#
#
# NOTE 7:
#     Inheritance Notes:
#     We can pass these methods and attributes to another class which was done for the MakeNote class. This is done using
#     super().__init__(master) which allows the tk.Button and all its button attributes and functionality
#     to be passed from the the MainWindow class to the MakeNote cla
#
# NOTE 8:
#     Abstraction Notes:
#     Abstraction is a thought process used in breaking down coding into steps. The first level is breaking
#     down the codeing into steps. The second level noticing similarities in codes. The third level is noticing repeating elements.
#
# NOTE 9:
#     GitHub Notes:
#     I have found it a lot easier to use GitHub and the repositories through the GitHub Desktop App. You go to the document you want to edit, click on the drop down menu next to the edit button and click "open with GitHub Desktop". This wil allow the repository to be open on the VsCode and you can just need to click 2 buttons on the GitHub Desktop app when you want to push and pull the commits. I found this easier than using the token.
#
# NOTE 10:
#     Importance of README:
#     README are often included with the code file. README are important as they often contain important information and notes on the code such as how to use the code/app, bugs, errors, and anuthing else important.

# %% [markdown]
# #### Insert your code below

# %% [markdown]
# In the cell below, insert your complete, modified code for your final note app. Include comments in your code that clearly identify each of your three improvements. Include additional comments as necessary.
# If your code requires an external note file, include the code to load that file from your github repository. If you load a file on the local drive, include code to delete that file when the program ends.

# %%
# insert your complete, modified code here. Use additional cells if needed.

# imports
import tkinter as tk
from tkinter import ttk
import datetime  # one module for working with dates and times


#  ATTENTION!!!!!!!
#IMPORTANT NOTES ABOUT THIS CODE !!!
#IMPORTANT NOTES ABOUT THIS CODE !!! 

# A txt file NAMED 'INST326_NOTEBOOK.txt' NEEDS TO BE MADE BEFORE RUNNING THE CODE
# THE CODE BELOW IS GIVEN TO BE RUN TO CREATE THE TXT FILE IF NEEDED
# UNCOMMENT THE CODE AND RUN THIS CODE ONCE TO CREATE THE TXT FILE

file_name = "INST326_NOTEBOOK.txt"
with open(file_name, 'w') as file:
    file.write("INST326 notebook.\n")
print(f"File '{file_name}' has been created.")


# WHEN VIEWING THE NOTEBOOK, YOU SHOULD BE USING LIGHT MODE 
# OR ELSE YOU CANNOT SEE THE CREATED AT AND EDIT AT LABELS





# The MainWindow class creates a custom GUI window based on the tkinter window (tk.Tk)
# It has an __init__() method, and three additional methods (new_note(), open_notebook(), and save_notebook())
# These methods correspond to new, open, and save buttons in the window.
# The new_note method calls the NoteForm class to create a new note form top level window.

class MainWindow(tk.Tk):
    def __init__(self):  # initialize the main window
        super().__init__()  # initialize it as a tkinter window

        self.geometry("600x400")  # set the default window size
        self.title('Notebook')  # set the default window title

        # create a frame for the scroll wheel
        main_frame = tk.Frame(self)
        main_frame.pack(fill=tk.BOTH, expand=True)

        # add a canvas
        canvas = tk.Canvas(main_frame)
        canvas.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

        # add the scrollbar
        scrollbar = tk.Scrollbar(main_frame, orient=tk.VERTICAL, command=canvas.yview)
        scrollbar.pack(side=tk.RIGHT, fill=tk.Y)

        # configures the Canvas
        canvas.configure(yscrollcommand=scrollbar.set)
        canvas.bind('<Configure>', lambda e: canvas.configure(scrollregion=canvas.bbox("all")))

        # create a frame inside the Canvas
        self.notebook_frame = tk.Frame(canvas)
        canvas.create_window((0, 0), window=self.notebook_frame, anchor=tk.NW)

        self.notebook = []  # initialize an attribute named 'notebook' as an empty list
        self.current_note = None

        create_button = tk.Button(self.notebook_frame, text='Create New Note', command=self.new_note)
        create_button.grid(row=0, column=0, padx=10, pady=10)

        save_button = tk.Button(self.notebook_frame, text='Save File', command=self.save_notebook)
        save_button.grid(row=0, column=1, padx=10, pady=10)

        quit_button = tk.Button(self.notebook_frame, text='Quit Application', command=self.destroy)
        quit_button.grid(row=0, column=2, padx=10, pady=10)

        title_label = tk.Label(self.notebook_frame, text='Notes')
        title_label.grid(row=1, column=0, padx=2, pady=2)

        self.read_notebook_file()
        self.refresh_notes_list()

        self.mainloop()

    def read_notebook_file(self):
        file = open('INST326_NOTEBOOK.txt', 'r')
        notes = file.readlines()
        for note in notes:
            fields = note.split('\t')
            if len(fields) < 8:
                continue
            new_note_dict = {'title': fields[0], 'text': fields[1], 'code_text': fields[2],
                         'author': fields[3], 'links': fields[4], 'tags': fields[5]}
            created_at = datetime.datetime.fromisoformat(fields[6].strip())
            if fields[7].strip():  
                last_edited = datetime.datetime.fromisoformat(fields[7].strip())
            else:
                last_edited = None
            new_note = Note(new_note_dict, created_at, last_edited)
            self.notebook.append(new_note)


    def refresh_notes_list(self):
        i = 2
        for note in self.notebook:
            self.current_note = note
            note_button = tk.Button(self.notebook_frame, text=note.title,
                                    command=lambda current_note=note: self.open_notebook(current_note))
            note_button.grid(row=i, column=0, padx=2, pady=2, sticky='E')
            i += 1

    def new_note(self):
        note_window = NoteForm(self, self.notebook, None)
        return None

    def open_notebook(self, current_note):
        self.current_note = current_note
        note_window = NoteForm(self, self.notebook, self.current_note)
        return None

    def save_notebook(self):
        with open("INST326_NOTEBOOK.txt", "w") as f:
            for note in self.notebook:
                if note.last_edited is not None:
                    last_edited = note.last_edited.isoformat()
                else:
                    last_edited = ""
                f.write(f"\n{note.title}\t{note.text}\t{note.code_text}\t{note.author}\t{note.links}\t{note.tags}\t{note.created_at.isoformat()}\t{last_edited}")
        return None



# the NoteForm() class creates a Toplevel window that is a note form containing fields for
# data entry for title, text, link, and tags. It also calculates a meta field with date, time, and timezone
# the Noteform class has an __init__() method, and a submit() method that is called by a submit button
# the class may contain additional methods to perform tasks like calculating the metadata, for example
# the submit method calls the MakeNote class that transforms the the entered data into a new note object.

class NoteForm(tk.Toplevel):
    def __init__(self, master, notebook, note):  # initialize the new object
        super().__init__(master)  # initialize it as a toplevel window
        self.notebook = notebook
        self.current_note = note

        # Add a Frame for the scrollable area
        main_frame = tk.Frame(self)
        main_frame.pack(fill=tk.BOTH, expand=True)

        # Add a Canvas
        canvas = tk.Canvas(main_frame)
        canvas.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

        # Add a scrollbar
        scrollbar = tk.Scrollbar(main_frame, orient=tk.VERTICAL, command=canvas.yview)
        scrollbar.pack(side=tk.RIGHT, fill=tk.Y)

        # Configure the Canvas
        canvas.configure(yscrollcommand=scrollbar.set)
        canvas.bind('<Configure>', lambda e: canvas.configure(scrollregion=canvas.bbox("all")))

        # Create another frame inside the Canvas
        self.note_form_frame = tk.Frame(canvas)
        canvas.create_window((0, 0), window=self.note_form_frame, anchor=tk.NW)

        # title
        title_label = tk.Label(self.note_form_frame, bg='light gray', text='Note Title:')
        self.note_title = tk.Entry(self.note_form_frame, width=80)

        title_label.grid(row=0, column=0, padx=2, pady=2, sticky='E')
        self.note_title.grid(row=0, column=1, padx=10, pady=2, sticky='W')

        # text
        text_label = tk.Label(self.note_form_frame, bg='light gray', text='Note Text:')
        self.note_text = tk.Text(self.note_form_frame, height=10, width=60)
        text_scroll = tk.Scrollbar(self.note_form_frame, orient=tk.VERTICAL, command=self.note_text.yview)

        text_label.grid(row=1, column=0, padx=2, pady=2, sticky='E')
        self.note_text.grid(row=1, column=1, padx=10, pady=2, sticky='W')
        text_scroll.grid(row=1, column=2, sticky='NS')
        self.note_text.config(yscrollcommand=text_scroll.set)

        # code text
        self.code_text = tk.StringVar()

        code_label = tk.Label(self.note_form_frame, bg='light gray', text='Code Text:')
        self.code_entry = tk.Text(self.note_form_frame, height=10, width=60)
        code_scroll = tk.Scrollbar(self.note_form_frame, orient=tk.VERTICAL, command=self.code_entry.yview)

        code_label.grid(row=2, column=0, padx=2, pady=2, sticky='E')
        self.code_entry.grid(row=2, column=1, padx=10, pady=10, sticky='W')
        code_scroll.grid(row=2, column=2, sticky='NS')
        self.code_entry.config(yscrollcommand=code_scroll.set)

        # edit code button
        edit_code_button = tk.Button(self.note_form_frame, text='Edit Code', command=self.edit_code)
        edit_code_button.grid(row=3, column=0, padx=10, pady=10, sticky='W')

        # save edit button
        save_edit_button = tk.Button(self.note_form_frame, text='Save Edit', command=self.save_edit)
        save_edit_button.grid(row=3, column=1, padx=10, pady=10, sticky='W')

        # author
        author_label = tk.Label(self.note_form_frame, bg='light gray', text='author:')
        self.note_author = tk.Entry(self.note_form_frame, width=80)

        author_label.grid(row=4, column=0, padx=2, pady=2, sticky='E')
        self.note_author.grid(row=4, column=1, padx=10, pady=10, sticky='W')

        # links
        links_label = tk.Label(self.note_form_frame, bg='light gray', text='Note Links:')
        self.note_links = tk.Entry(self.note_form_frame, width=80)

        links_label.grid(row=5, column=0, padx=2, pady=2, sticky='E')
        self.note_links.grid(row=5, column=1, padx=10, pady=10, sticky='W')

        # tags
        tags_label = tk.Label(self.note_form_frame, bg='light gray', text='Note Tags:')
        self.note_tags = tk.Entry(self.note_form_frame, width=80)

        tags_label.grid(row=6, column=0, padx=2, pady=2, sticky='E')
        self.note_tags.grid(row=6, column=1, padx=10, pady=2, sticky='W')

        # submit button
        submit_button = tk.Button(self.note_form_frame, text='Submit', command=self.submit)
        submit_button.grid(row=7, column=1, padx=10, pady=10, sticky='W')

        # created_at label
        created_at_label = tk.Label(self.note_form_frame, bg='light gray', text='Created At:')
        self.created_at_display = tk.Label(self.note_form_frame, bg='light gray', fg='black')

        created_at_label.grid(row=8, column=0, padx=2, pady=2, sticky='E')
        self.created_at_display.grid(row=8, column=1, padx=10, pady=2, sticky='W')

        # last_edited label
        last_edited_label = tk.Label(self.note_form_frame, bg='light gray', text='Last Edited:')
        self.last_edited_display = tk.Label(self.note_form_frame, bg='light gray', fg='black')

        last_edited_label.grid(row=9, column=0, padx=2, pady=2, sticky='E')
        self.last_edited_display.grid(row=9, column=1, padx=10, pady=2, sticky='W')

        # if viewing an existing note, remove submit button, disable inputs, and displays created_at and last_edited
        if note is None:
            self.last_edited_display.config(text='')
        else:
            self.note_title.insert(0, note.title)
            self.note_text.insert("1.0", note.text)
            self.code_entry.insert("1.0", note.code_text)
            self.note_author.insert(0, note.author)
            self.note_links.insert(0, note.links)
            self.note_tags.insert(0, note.tags)
            self.created_at_display.config(text=note.created_at.strftime("%m/%d/%y %H:%M"))
            if note.last_edited:
                self.last_edited_display.config(text=note.last_edited.strftime("%m/%d/%y %H:%M"))


    def edit_code(self):
        if not self.code_text_editable:
            self.code_entry.config(state=tk.NORMAL)
            self.code_text_editable = True
        else:
            self.code_entry.config(state=tk.DISABLED)
            self.code_text_editable = False

    def save_edit(self):
        if self.current_note:
            self.current_note.code_text = self.code_entry.get("1.0", "end-1c")
            self.current_note.last_edited = datetime.datetime.now()
            self.last_edited_display.config(text=self.current_note.last_edited.strftime("%m/%d/%y %H:%M"))
            self.code_entry.config(state=tk.DISABLED)
            self.code_text_editable = False

    def submit(self):
        new_note_dict = {'title': self.note_title.get(),
                         'text': self.note_text.get("1.0", "end-1c"),
                         'code_text': self.code_entry.get("1.0", "end-1c"),
                         'author': self.note_author.get(),
                         'links': self.note_links.get(),
                         'tags': self.note_tags.get()}
        if self.current_note:
            new_note = Note(new_note_dict, self.current_note.created_at, self.current_note.last_edited)
        else:
            new_note = Note(new_note_dict)

        index = self.notebook.index(self.current_note) if self.current_note else None
        if index is not None:
            self.notebook[index] = new_note
        else:
            self.notebook.append(new_note)

        self.destroy()
        self.master.refresh_notes_list()


# The Note class takes a dictionary containing the data entered into the form window,
# and transforms it into a new note object.
# At present the note objects have attributes but no methods.

class Note():
    def __init__(self, note_dict, created_at=None, last_edited=None):
        self.title = note_dict["title"]
        self.text = note_dict["text"]
        self.author = note_dict["author"]
        self.links = note_dict["links"]
        self.tags = note_dict["tags"]
        if "code_text" in note_dict:
            self.code_text = note_dict["code_text"]
        if created_at:
            self.created_at = created_at
        else:
            self.created_at = datetime.datetime.now()
        self.last_edited = last_edited


# Snippet Class
class Snippet(tk.Toplevel):
    def __init__(self, master, snippet):
        super().__init__(master)
        self.snippet = snippet

        # code text field
        code_label = tk.Label(self, bg='light gray', text='Code Text:')
        self.code_text = tk.Text(self, height=5, width=60)

        code_label.grid(row=1, column=0, padx=2, pady=2, sticky='E')
        self.code_text.grid(row=1, column=1, padx=10, pady=2, sticky='W')

        # if viewing an existing snippet, keeps the existed text there
        if self.snippet:
            self.code_text.insert("1.0", self.snippet.code_text)

        # submit button
        save_edit_button = tk.Button(self, text='Save Edit', command=self.save_edit)
        save_edit_button.grid(row=2, column=1, padx=10, pady=10, sticky='W')

    def save_edit(self):
        if self.snippet:
            self.snippet.code_text = self.code_text.get("1.0", "end-1c")
        else:
            self.master.code_text.set(self.code_text.get("1.0", "end-1c"))
        self.destroy()


# main execution
if __name__ == '__main__':
    main_window = MainWindow()  # this creates a notebook / main window called main_window. You may change the name if you want
# Out:
# File 'INST326_NOTEBOOK.txt' has been created.
